# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy.stats as st
import numpy as np

# %%
df=pd.read_csv("/Users/Sanjay/Documents/SECOND YEAR STUFF/IDS/PROJECT/database.csv")

# %%
print(np.mean(df.Latitude))
# Out:
# 1.6790331197719317

# %%
print(np.median(df.Latitude))
# Out:
# -3.5685000000000002

# %%
plt.xlabel("LATITUDE")
plt.ylabel("FREQUENCY")
plt.title("FREQUENCY HISTOGRAM OF LATITUDE")
plt.hist(df.Latitude)
# Out:
# (array([ 184., 1391., 1804., 4537., 6018., 2984., 2416., 3401.,  564.,
#          113.]),
#  array([-77.08  , -60.7715, -44.463 , -28.1545, -11.846 ,   4.4625,
#          20.771 ,  37.0795,  53.388 ,  69.6965,  86.005 ]),
#  <a list of 10 Patch objects>)

# %%
plt.ylabel("LATITUDE")
plt.title("BOX PLOT OF LATITUDE")
plt.boxplot(df.Latitude)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a0ea99c18>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a0eaa3518>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a0ea99ac8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a0eaa3d68>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a0eaaf1d0>],
#  'means': []}

# %%
print(np.mean(df.Longitude))
# Out:
# 39.6399607380701

# %%
print(np.median(df.Longitude))
# Out:
# 103.982

# %%
plt.xlabel("LONGITUDE")
plt.ylabel("FREQUENCY")
plt.title("FREQUENCY HISTOGRAM OF LONGITUDE")
plt.hist(df.Longitude)
# Out:
# (array([3358.,  936., 2006., 1338., 1027.,  533.,  851., 1796., 5526.,
#         6041.]),
#  array([-1.799970e+02, -1.439975e+02, -1.079980e+02, -7.199850e+01,
#         -3.599900e+01,  5.000000e-04,  3.600000e+01,  7.199950e+01,
#          1.079990e+02,  1.439985e+02,  1.799980e+02]),
#  <a list of 10 Patch objects>)

# %%
plt.ylabel("LONGITUDE")
plt.title("BOX PLOT OF LONGITUDE")
plt.boxplot(df.Longitude)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a0ef42940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a0ef49240>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a0ef427f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a0ef49a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a0ef49eb8>],
#  'means': []}

# %%
print(np.mean(df.Magnitude))
# Out:
# 5.882530753460003

# %%
print(np.median(df.Magnitude))
# Out:
# 5.7

# %%
plt.xlabel("MAGNITUDE")
plt.ylabel("FREQUENCY")
plt.title("FREQUENCY HISTOGRAM OF MAGNITUDE")
plt.hist(df.Magnitude)
# Out:
# (array([1.4107e+04, 5.6570e+03, 1.8100e+03, 1.1000e+03, 3.9300e+02,
#         2.1400e+02, 1.0400e+02, 1.9000e+01, 5.0000e+00, 3.0000e+00]),
#  array([5.5 , 5.86, 6.22, 6.58, 6.94, 7.3 , 7.66, 8.02, 8.38, 8.74, 9.1 ]),
#  <a list of 10 Patch objects>)

# %%
plt.ylabel("MAGNITUDE")
plt.title("BOX PLOT OF MAGNITUDE")
plt.boxplot(df.Magnitude)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a0f4e45c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a0f4e4e80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a0f4e4470>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a0f073710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a0f073b38>],
#  'means': []}

# %%
plt.xlabel("DEPTH")
plt.ylabel("FREQUENCY")
plt.title("FREQUENCY HISTOGRAM OF DEPTH")
plt.hist(df.Depth)
# Out:
# (array([18631.,  2159.,   917.,   346.,    92.,   174.,   144.,   311.,
#           539.,    99.]),
#  array([ -1.1 ,  69.01, 139.12, 209.23, 279.34, 349.45, 419.56, 489.67,
#         559.78, 629.89, 700.  ]),
#  <a list of 10 Patch objects>)

# %%
print(np.std(df.Latitude))
# Out:
# 30.112539777576316

# %%
print(np.std(df.Longitude))
# Out:
# 125.50927797139161

# %%
print(np.std(df.Magnitude))
# Out:
# 0.423056603988658

# %%
print(np.mean(df.Depth))
# Out:
# 70.76791124209808

# %%
print(np.median(df.Depth))
# Out:
# 33.0

# %%
print(np.std(df.Depth))
# Out:
# 122.6492782644396

# %%
plt.ylabel("DEPTH")
plt.title("BOX PLOT OF DEPTH")
plt.boxplot(df.Depth)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a0f77e828>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a0f785128>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a0f77e6d8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a0f785978>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a0f785da0>],
#  'means': []}

# %%
q1,q2,q3=np.percentile(df.Magnitude,[25,50,75])
print(np.percentile(df.Magnitude,100)-np.percentile(df.Magnitude,0))
print(q3-q1)
# Out:
# 3.5999999999999996
# 0.40000000000000036

# %%
q1,q2,q3=np.percentile(df.Latitude,[25,50,75])
print(np.percentile(df.Latitude,100)-np.percentile(df.Latitude,0))
print(q3-q1)
# Out:
# 163.08499999999998
# 44.84375

# %%
q1,q2,q3=np.percentile(df.Longitude,[25,50,75])
print(np.percentile(df.Longitude,100)-np.percentile(df.Longitude,0))
print(q3-q1)
# Out:
# 359.995
# 221.376

# %%
q1,q2,q3=np.percentile(df.Depth,[25,50,75])
print(np.percentile(df.Depth,100)-np.percentile(df.Depth,0))
print(q3-q1)
# Out:
# 701.1
# 39.4775

# %%
plt.xlabel("LATITUDE")
plt.ylabel("MAGNITUDE")
plt.title("SCATTER PLOT OF LATITUDE VERSUS MAGNITUDE")
plt.scatter(df.Latitude,df.Magnitude)

# %%
plt.xlabel("LONGITUDE")
plt.ylabel("MAGNITUDE")
plt.title("SCATTER PLOT OF LONGITUDE VERSUS MAGNITUDE")
plt.scatter(df.Longitude,df.Magnitude)

# %%
plt.xlabel("DEPTH")
plt.ylabel("MAGNITUDE")
plt.title("SCATTER PLOT OF DEPTH VERSUS MAGNITUDE")
plt.scatter(df.Depth,df.Magnitude)

# %%
li=[]
di={}
s=set()
for i,j in df.Date.iteritems():
    j=j[-2:]
    li.append(j)
    s.add(j)
for i in s:
    di[i]=0
    for j in li:
        if(j==i)
            di[i]+=1
li1=[]
for i in di:
    li1.append(di[i])
# Out:
#   File "<ipython-input-30-0d53a3d68ee8>", line 11
#     if(j==i)
#             ^
# SyntaxError: invalid syntax

# %%
li=[]
di={}
s=set()
for i,j in df.Date.iteritems():
    j=j[-2:]
    if(j<'20'):
        j+='20'
    else:
        j+='19'
    j=j[-2:]+j[:2]
    if(j!='200Z'):
        di[j]=0
print(di)
for i,j in df.Date.iteritems():
    j=j[-2:]
    if(j<'20'):
        j+='20'
    else:
        j+='19'
    j=j[-2:]+j[:2]
    if(j!='200Z'):
        di[j]+=df.Latitude[i]
for i in di:
    li.append(int(i))
print(li)
li1=[]
for i in di:
    li1.append(di[i])
print(li1)
for i in li1:
    
print(len(li),len(li1))

# %%
li=[]
di={}
s=set()
for i,j in df.Date.iteritems():
    j=j[-2:]
    if(j<'20'):
        j+='20'
    else:
        j+='19'
    j=j[-2:]+j[:2]
    if(j!='200Z'):
        di[j]=0
print(di)
for i,j in df.Date.iteritems():
    j=j[-2:]
    if(j<'20'):
        j+='20'
    else:
        j+='19'
    j=j[-2:]+j[:2]
    if(j!='200Z'):
        di[j]+=1
for i in di:
    li.append(int(i))
print(li)
li1=[]
for i in di:
    li1.append(di[i])
print(li1)
print(len(li),len(li1))
# Out:
# {'1965': 0, '1966': 0, '1967': 0, '1968': 0, '1969': 0, '1970': 0, '1971': 0, '1972': 0, '1973': 0, '1974': 0, '1975': 0, '1976': 0, '1977': 0, '1978': 0, '1979': 0, '1980': 0, '1981': 0, '1982': 0, '1983': 0, '1984': 0, '1985': 0, '1986': 0, '1987': 0, '1988': 0, '1989': 0, '1990': 0, '1991': 0, '1992': 0, '1993': 0, '1994': 0, '1995': 0, '1996': 0, '1997': 0, '1998': 0, '1999': 0, '2000': 0, '2001': 0, '2002': 0, '2003': 0, '2004': 0, '2005': 0, '2006': 0, '2007': 0, '2008': 0, '2009': 0, '2010': 0, '2011': 0, '2012': 0, '2013': 0, '2014': 0, '2015': 0, '2016': 0}
# [1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]
# ...

# %%
import numpy as np 
import matplotlib.pyplot as plt 

def estimate_coef(x, y): 
	# number of observations/points 
	n = np.size(x) 

	# mean of x and y vector 
	m_x, m_y = np.mean(x), np.mean(y) 

	# calculating cross-deviation and deviation about x 
	SS_xy = np.sum(y*x - n*m_y*m_x) 
	SS_xx = np.sum(x*x - n*m_x*m_x) 

	# calculating regression coefficients 
	b_1 = SS_xy / SS_xx 
	b_0 = m_y - b_1*m_x 

	return(b_0, b_1) 

def plot_regression_line(x, y, b): 
	# plotting the actual points as scatter plot 
	plt.scatter(x, y, color = "m", 
			marker = "o", s = 30) 

	# predicted response vector 
	y_pred = b[0] + b[1]*x 

	# plotting the regression line 
	plt.plot(x, y_pred, color = "g") 

	# putting labels 
	plt.xlabel('x') 
	plt.ylabel('y') 

	# function to show plot 
	plt.show() 

def main(): 
    # observations 
    x = np.array(li)
    y = np.array(li1)
    #print(len(x),len(y))

    #estimating coefficients 
    b = estimate_coef(x, y) 
    print("Estimated coefficients:\nb_0 = {} \ \nb_1 = {}".format(b[0], b[1])) 

    # plotting regression line 
    plot_regression_line(x, y, b) 

if __name__ == "__main__": 
	main()
# Out:
# Estimated coefficients:
# b_0 = 0.0089557243101126 \
# b_1 = 0.22615630303881779

# %%
li2=["1965-1975","1975-1985","1985-1995","1995-2005","2005-2016"]
li3=[0,0,0,0,0]
for i in di:
    if(i>='1965' and i<'1975'):
        li3[0]+=di[i]
    if(i>='1975' and i<'1985'):
        li3[1]+=di[i]
    if(i>='1985' and i<'1995'):
        li3[2]+=di[i]
    if(i>='1995' and i<'2005'):
        li3[3]+=di[i]
    if(i>='2005' and i<='2016'):
        li3[4]+=di[i]
print(li3)
# Out:
# [3337, 4009, 4898, 4918, 6250]

# %%
plt.title("NUMBER OF EARTHQUAKES BY YEAR RANGE")
plt.ylabel("NUMBER")
plt.xlabel("YEAR RANGE")
plt.bar(li2,li3)
# Out:
# <BarContainer object of 5 artists>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import numpy as np
from sklearn.metrics import r2_score
import pandas as pd

df=pd.read_csv("/Users/Sanjay/Documents/SECOND YEAR STUFF/IDS/PROJECT/database.csv")
x = np.array(li)
y = np.array(li1)
#print(x,y)
#plt.plot(x,y,'ro')
b1 , b0 = np.polyfit(x,y, deg = 1)
print('y_hat = ', b0 , '+', b1,'x')
yp = b0 + b1 * x
#plt.plot(x, yp)
#plt.show()

#coefficient of determination
print(r2_score(y,yp))

#plt.plot(y, yp, 'ro')

residuals = y - yp
plt.plot(yp, residuals, 'ro')
plt.hlines(0, 0, 12000)
# Out:
# y_hat =  -8033.965679159878 + 4.262315376077845 x
# 0.5028789759819992

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import numpy as np
from sklearn.metrics import r2_score
import pandas as pd

df = pd.read_csv('/Users/Sanjay/Documents/SECOND YEAR STUFF/IDS/PROJECT/database.csv')

x = np.array(li)
y = np.array(li1)

b1 , b0 = np.polyfit(x,y, deg=1)
yp = b0 + b1 * x
plt.title("LINEAR REGRESSION PLOT FOR EARTHQUAKE FREQUENCY")
plt.ylabel("NUMBER OF EARTHQUAKES")
plt.xlabel("YEAR")
plt.plot(x, y, 'ro')
plt.plot(x, yp)

# %%
li3=[]
di1={}
s=set()
for i,j in df.Date.iteritems():
    j=j[-2:]
    if(j<'20'):
        j+='20'
    else:
        j+='19'
    j=j[-2:]+j[:2]
    if(j!='200Z'):
        di1[int(j)]=0
print(di1)
for i,j in df.Date.iteritems():
    j=j[-2:]
    if(j<'20'):
        j+='20'
    else:
        j+='19'
    j=j[-2:]+j[:2]
    if(j!='200Z'):
        di1[int(j)]+=df.Latitude[i]
for i in li:
    li3.append(di1[i]/li1[i-1965])
print(li3)
# Out:
# {1965: 0, 1966: 0, 1967: 0, 1968: 0, 1969: 0, 1970: 0, 1971: 0, 1972: 0, 1973: 0, 1974: 0, 1975: 0, 1976: 0, 1977: 0, 1978: 0, 1979: 0, 1980: 0, 1981: 0, 1982: 0, 1983: 0, 1984: 0, 1985: 0, 1986: 0, 1987: 0, 1988: 0, 1989: 0, 1990: 0, 1991: 0, 1992: 0, 1993: 0, 1994: 0, 1995: 0, 1996: 0, 1997: 0, 1998: 0, 1999: 0, 2000: 0, 2001: 0, 2002: 0, 2003: 0, 2004: 0, 2005: 0, 2006: 0, 2007: 0, 2008: 0, 2009: 0, 2010: 0, 2011: 0, 2012: 0, 2013: 0, 2014: 0, 2015: 0, 2016: 0}
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import numpy as np
from sklearn.metrics import r2_score
import pandas as pd

df = pd.read_csv('/Users/Sanjay/Documents/SECOND YEAR STUFF/IDS/PROJECT/database.csv')

x = np.array(li)
y = np.array(li3)

b1 , b0 = np.polyfit(x,y, deg=1)
yp = b0 + b1 * x
plt.title("LINEAR REGRESSION PLOT FOR EARTHQUAKE LATITUDE")
plt.ylabel("AVERAGE LATITUDE")
plt.xlabel("YEAR")
plt.plot(x, y, 'ro')
plt.plot(x, yp)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import numpy as np
from sklearn.metrics import r2_score
import pandas as pd

df=pd.read_csv("/Users/Sanjay/Documents/SECOND YEAR STUFF/IDS/PROJECT/database.csv")
x = np.array(li)
y = np.array(li3)
#print(x,y)
#plt.plot(x,y,'ro')
b1 , b0 = np.polyfit(x,y, deg = 1)
print('y_hat = ', b0 , '+', b1,'x')
yp = b0 + b1 * x
#plt.plot(x, yp)
#plt.show()

#coefficient of determination
print(r2_score(y,yp))

#plt.plot(y, yp, 'ro')

residuals = y - yp
plt.plot(yp, residuals, 'ro')
plt.hlines(0, 0, 12000)
# Out:
# y_hat =  374.0683965787041 + -0.18688905238003772 x
# 0.35335916601233186

# %%
li6=[]
di1={}
s=set()
for i,j in df.Date.iteritems():
    j=j[-2:]
    if(j<'20'):
        j+='20'
    else:
        j+='19'
    j=j[-2:]+j[:2]
    if(j!='200Z'):
        di1[int(j)]=0
print(di1)
for i,j in df.Date.iteritems():
    j=j[-2:]
    if(j<'20'):
        j+='20'
    else:
        j+='19'
    j=j[-2:]+j[:2]
    if(j!='200Z'):
        di1[int(j)]+=df.Longitude[i]
for i in li:
    li6.append(di1[i]/li1[i-1965])
print(li6)
# Out:
# {1965: 0, 1966: 0, 1967: 0, 1968: 0, 1969: 0, 1970: 0, 1971: 0, 1972: 0, 1973: 0, 1974: 0, 1975: 0, 1976: 0, 1977: 0, 1978: 0, 1979: 0, 1980: 0, 1981: 0, 1982: 0, 1983: 0, 1984: 0, 1985: 0, 1986: 0, 1987: 0, 1988: 0, 1989: 0, 1990: 0, 1991: 0, 1992: 0, 1993: 0, 1994: 0, 1995: 0, 1996: 0, 1997: 0, 1998: 0, 1999: 0, 2000: 0, 2001: 0, 2002: 0, 2003: 0, 2004: 0, 2005: 0, 2006: 0, 2007: 0, 2008: 0, 2009: 0, 2010: 0, 2011: 0, 2012: 0, 2013: 0, 2014: 0, 2015: 0, 2016: 0}
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import numpy as np
from sklearn.metrics import r2_score
import pandas as pd

df = pd.read_csv('/Users/Sanjay/Documents/SECOND YEAR STUFF/IDS/PROJECT/database.csv')

x = np.array(li)
y = np.array(li6)

b1 , b0 = np.polyfit(x,y, deg=1)
yp = b0 + b1 * x
plt.title("LINEAR REGRESSION PLOT FOR LONGITUDE")
plt.ylabel("AVERAGE LONGITUDE")
plt.xlabel("YEAR")
plt.plot(x, y, 'ro')
plt.plot(x, yp)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import numpy as np
from sklearn.metrics import r2_score
import pandas as pd

df=pd.read_csv("/Users/Sanjay/Documents/SECOND YEAR STUFF/IDS/PROJECT/database.csv")
x = np.array(li)
y = np.array(li6)
#print(x,y)
#plt.plot(x,y,'ro')
b1 , b0 = np.polyfit(x,y, deg = 1)
print('y_hat = ', b0 , '+', b1,'x')
yp = b0 + b1 * x
#plt.plot(x, yp)
#plt.show()

#coefficient of determination
print(r2_score(y,yp))

#plt.plot(y, yp, 'ro')

residuals = y - yp
plt.plot(yp, residuals, 'ro')
plt.hlines(0, 0, 12000)
# Out:
# y_hat =  866.9172861753415 + -0.4152136611659762 x
# 0.19213320957387303

# %%
print("             PREDICTIONS FOR 2017 USING REGRESSION")
print("---------------------------------------------------------------")
print("NUMBER OF EARTHQUAKES :",int(-8033.965679159878 + 4.262315376077845*2017))
print("MOST LIKELY LATITUDE FOR EARTHQUAKES :",374.0683965787041 + -0.18688905238003772*2017)
print("MOST LIKELY LONGITUDE FOR EARTHQUAKES :",866.9172861753415 + -0.4152136611659762*2017)
print("MOST LIKELY MAGNITUDE OF EARTHQUAKES :",8.647845717173066 + -0.0013865900762512619*2017)
print("---------------------------------------------------------------")
# Out:
#              PREDICTIONS FOR 2017 USING REGRESSION
# ---------------------------------------------------------------
# NUMBER OF EARTHQUAKES : 563
# MOST LIKELY LATITUDE FOR EARTHQUAKES : -2.8868220718320003
# MOST LIKELY LONGITUDE FOR EARTHQUAKES : 29.431331603567514
# MOST LIKELY MAGNITUDE OF EARTHQUAKES : 5.8510935333742715
# ---------------------------------------------------------------

# %%
li9=[]
di1={}
s=set()
for i,j in df.Date.iteritems():
    j=j[-2:]
    if(j<'20'):
        j+='20'
    else:
        j+='19'
    j=j[-2:]+j[:2]
    if(j!='200Z'):
        di1[int(j)]=0
print(di1)
for i,j in df.Date.iteritems():
    j=j[-2:]
    if(j<'20'):
        j+='20'
    else:
        j+='19'
    j=j[-2:]+j[:2]
    if(j!='200Z' and df.Magnitude[i]>6.5):
        di1[int(j)]+=1
for i in li:
    li9.append(di1[i])
print(li9)
# Out:
# {1965: 0, 1966: 0, 1967: 0, 1968: 0, 1969: 0, 1970: 0, 1971: 0, 1972: 0, 1973: 0, 1974: 0, 1975: 0, 1976: 0, 1977: 0, 1978: 0, 1979: 0, 1980: 0, 1981: 0, 1982: 0, 1983: 0, 1984: 0, 1985: 0, 1986: 0, 1987: 0, 1988: 0, 1989: 0, 1990: 0, 1991: 0, 1992: 0, 1993: 0, 1994: 0, 1995: 0, 1996: 0, 1997: 0, 1998: 0, 1999: 0, 2000: 0, 2001: 0, 2002: 0, 2003: 0, 2004: 0, 2005: 0, 2006: 0, 2007: 0, 2008: 0, 2009: 0, 2010: 0, 2011: 0, 2012: 0, 2013: 0, 2014: 0, 2015: 0, 2016: 0}
# [35, 29, 31, 38, 37, 44, 45, 35, 22, 23, 26, 29, 23, 29, 23, 20, 26, 20, 41, 34, 31, 26, 46, 38, 25, 40, 38, 40, 39, 37, 53, 47, 32, 36, 32, 35, 33, 27, 40, 38, 36, 33, 46, 37, 41, 49, 46, 36, 44, 39, 48, 41]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import numpy as np
from sklearn.metrics import r2_score
import pandas as pd

df = pd.read_csv('/Users/Sanjay/Documents/SECOND YEAR STUFF/IDS/PROJECT/database.csv')

x = np.array(li)
y = np.array(li8)

b1 , b0 = np.polyfit(x,y, deg=1)
yp = b0 + b1 * x
plt.title("LINEAR REGRESSION PLOT FOR MAGNITUDE")
plt.ylabel("AVERAGE MAGNITUDE")
plt.xlabel("YEAR")
plt.plot(x, y, 'ro')
plt.plot(x, yp)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import numpy as np
from sklearn.metrics import r2_score
import pandas as pd

df=pd.read_csv("/Users/Sanjay/Documents/SECOND YEAR STUFF/IDS/PROJECT/database.csv")
x = np.array(li)
y = np.array(li8)
#print(x,y)
#plt.plot(x,y,'ro')
b1 , b0 = np.polyfit(x,y, deg = 1)
print('y_hat = ', b0 , '+', b1,'x')
yp = b0 + b1 * x
#plt.plot(x, yp)
#plt.show()

#coefficient of determination
print(r2_score(y,yp))

#plt.plot(y, yp, 'ro')

residuals = y - yp
plt.plot(yp, residuals, 'ro')
plt.hlines(0, 0, 12000)
# Out:
# y_hat =  8.647845717173066 + -0.0013865900762512619 x
# 0.11694966682219143

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import numpy as np
from sklearn.metrics import r2_score
import pandas as pd

df = pd.read_csv('/Users/Sanjay/Documents/SECOND YEAR STUFF/IDS/PROJECT/database.csv')

x = np.array(li)
y = np.array(li9)

b1 , b0 = np.polyfit(x,y, deg=1)
yp = b0 + b1 * x
plt.title("LINEAR REGRESSION PLOT FOR HIGH MAGNITUDE")
plt.ylabel("NUMBER OF HIGH MAGNITUDE EARTHQUAKES")
plt.xlabel("YEAR")
plt.plot(x, y, 'ro')
plt.plot(x, yp)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy.stats as st
import numpy as np
df=pd.read_csv("/Users/Sanjay/Documents/SECOND YEAR STUFF/IDS/PROJECT/database.csv")
latlow=float(input("Enter lower latitude :"))
lathigh=float(input("Enter higher latitude :"))
longlow=float(input("Enter lower longitude :"))
longhigh=float(input("Enter higher longitude :"))
count=0
summag=0
sumdepth=0
for row in df.iterrows():
    if((row[1][2]>=latlow and row[1][2]<=lathigh) and (row[1][3]>=longlow and row[1][3]<=longhigh)):
        count+=1
        summag+=row[1][8]
        sumdepth+=row[1][5]
prob=count/23412
mag=summag/count
depth=sumdepth/count
print("Probability of earthquake in given range of latitude and longitude :",prob)
print("Expected magnitude of earthquake within given coordinates :",mag)
print("Expected depth of earthquake within given coordinates :",depth)
# Out:
# Enter lower latitude :-15
# Enter higher latitude :15
# Enter lower longitude :-20
# Enter higher longitude :20
# Probability of earthquake in given range of latitude and longitude : 0.004997437211686315
# Expected magnitude of earthquake within given coordinates : 5.861538461538463
# Expected depth of earthquake within given coordinates : 12.608803418803419

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import math
import random

# %%
stats.ttest_1samp(a= df.Latitude.sample(15),               # Sample data
                 popmean= np.mean(df.Latitude))  # Pop mean
# Out:
# Ttest_1sampResult(statistic=1.643537981320585, pvalue=0.12253243490982464)

# %%
stats.ttest_1samp(a= df.Longitude.sample(15),               # Sample data
                 popmean= np.mean(df.Longitude))  # Pop mean
# Out:
# Ttest_1sampResult(statistic=-0.8023360832446296, pvalue=0.4357674313730473)

# %%
stats.ttest_1samp(a= df.Magnitude.sample(100),               # Sample data
                 popmean= np.mean(df.Magnitude))  # Pop mean
# Out:
# Ttest_1sampResult(statistic=-2.955459284316684, pvalue=0.003902140750739512)

# %%
stats.ttest_1samp(a= df.Magnitude.sample(15),               # Sample data
                 popmean= np.mean(df.Magnitude))  # Pop mean
# Out:
# Ttest_1sampResult(statistic=-1.6971837275798083, pvalue=0.11177097626574918)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from math import sqrt
from scipy.stats import norm
df=pd.read_csv("/Users/Sanjay/Documents/SECOND YEAR STUFF/IDS/PROJECT/database.csv")
pop_mean = np.mean(df.Latitude)

def sampling(sample_size, no_of_samples):
    sample_means = []
    intervals = []
    count = 0
    for i in range(no_of_samples):
        sample = df.Latitude.sample(sample_size)
        sample_means.append(np.mean(sample))
        ci = norm.interval(0.95, np.mean(sample), 
                            np.std(sample, ddof =1)/sqrt(sample_size))
        intervals.append(ci)
        if pop_mean >= ci[0] and pop_mean <= ci[1]:
            count = count + 1
    print('Proportion of CIs covering Pop mean', count/no_of_samples)
    plt.figure(figsize=(15,5))
    plt.hlines(y = pop_mean, xmin = 0, xmax = 100, color ='r')
    plt.errorbar(np.arange(0.1, 100, 1), sample_means, fmt = 'o', yerr = [(upp - low)/2 for low, upp in intervals])
    plt.title("CONFIDENCE INTERVAL PLOT FOR LATITUDE")
    plt.show()
    
sampling(1000, 100)
# Out:
# Proportion of CIs covering Pop mean 0.96
